# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
de2engl = {"Montag": "Monday", "Dienstag": "Tuesday", "Mittwoch": "Wednesday",
           "Donnerstag": "Thursday", "Freitag": "Friday", "Samstag": "Saturday", "Sonntag": "Sunday"}
dictinary_list = []

for league in [1, 2]:
    if league == 1:
        R = range(63, 120)  # Year = 1900+k
    if league == 2:
        R = range(74, 120)  # Year = 1900+k

    for k in R:
        # First load a website to just see how many matchdays there are
        prefix = 19 if k < 100 else 20
        url = ('http://www.kicker.de/news/fussball/bundesliga/spieltag/'
               '{}-bundesliga/{}{:02d}-{:02d}/-1/0/spieltag.html'.format(league, prefix, k % 100, (k+1) % 100))
        page = requests.get(url)
        print(url)
        soup = BeautifulSoup(page.text, 'html.parser')  # Get website content
        matchdaytag = "kick__v100-gameList kick__module-margin"
        matchdays = soup.findAll("div", {"class": matchdaytag})

        for matchday in range(1, 1+len(matchdays)):  # The roughly 30 matchdays through the year
            url = "https://www.kicker.de/{}-bundesliga/spieltag/{}{:02d}-{:02d}/{}".format(
                league, prefix, k % 100, (k+1) % 100, matchday)
            page = requests.get(url)
            soup = BeautifulSoup(page.text, 'html.parser')  # Get website content

            matchdatestag = "kick__v100-gameList kick__module-margin"
            matchdates = soup.findAll("div", {"class": matchdatestag})
            for matchdate in matchdates:  # The weekday during which the matches take place
                weekdaytag = "kick__v100-gameList__header"
                st = matchdate.findAll("div", {"class": weekdaytag})[0].text.strip().split(",")[1]
                date = pd.to_datetime(st, format = "%d.%m.%Y",errors='coerce').date()
                dayofweek = matchdate.findAll("div", {"class": weekdaytag})[
                    0].text.strip().split(",")[0]
                matchtag = "kick__v100-gameList__gameRow"
                games = matchdate.findAll("div", {"class": matchtag})
                for game in games:  # All the games on a Friday, Saturday, ...
                    teamstag = "kick__v100-gameCell__team__name"
                    teams = game.findAll("div", {"class": teamstag})
                    resulttag = "kick__v100-scoreBoard kick__v100-scoreBoard--standard"
                    goalstag = "kick__v100-scoreBoard__scoreHolder__score"
                    goals = game.findAll("a", {"class": resulttag})[
                        0].findAll("div", {"class": goalstag})

                    aborted = False
                    annull = False
                    try:
                        home = teams[0].text.strip()
                        guest = teams[1].text.strip()
                        goalshome = int(goals[0].text)
                        goalsguest = int(goals[1].text)
                        goalshome_halftime = int(goals[2].text)
                        goalsguest_halftime = int(goals[3].text)
                    except:
                        # Two games got aborted and repeated. We do not have a half time score for these.
                        # We do store them in the databse, but set the "aborted" flag to be true.
                        # The games are found here:
                        # https://www.kicker.de/bundesliga/spieltag/1963-64/14/0
                        # https://www.kicker.de/bundesliga/spieltag/2007-08/28/0
                        # For four more games, the half time score was not available.

                        try:
                            abortedtag = "kick__v100-scoreBoard__scoreHolder__text"
                            status = game.findAll("div", {"class": abortedtag})
                            aborted = status[0].text == "abgr."
                        except:
                            pass

                        try:
                            annultag = "kick__v100-scoreBoard__dateHolder"
                            status = game.findAll("div", {"class": abortedtag})
                            annull = status[0].text == "annull."
                        except:
                            pass

                        goalshome_halftime = pd.NA
                        goalsguest_halftime = pd.NA

                    # In 1995/96 the 3 points rule for winner was introduced.
                    pointswinner = 3 if k >= 95 else 2
                    if goalshome == goalsguest:
                        pointshome, pointsguest = 1, 1
                    elif goalshome > goalsguest:
                        pointsguest, pointshome = pointswinner, 0
                    else:
                        pointsguest, pointshome = 0, pointswinner

                    entry = {'SeasonFrom': 1900+k,
                             'SeasonTo': 1901+k,
                             'Matchday': matchday,
                             'Day': de2engl[dayofweek],
                             'Date': date,
                             'Time': pd.NA,
                             'Home': home,
                             'Guest': guest,
                             'Score90': "{}:{}".format(goalshome, goalsguest),
                             'Score45': "{}:{}".format(goalshome_halftime, goalsguest_halftime),
                             'Score90Home': goalshome,
                             'Score90Guest': goalsguest,
                             'Score45Home': goalshome_halftime,
                             'Score45Guest': goalsguest_halftime,
                             'PointsHome': pointshome,
                             'PointsGuest': pointsguest,
                             'Aborted': aborted,
                             'Annulled': annull,
                             'League': "{}. Bundesliga".format(league)}
                    dictinary_list.append(entry)
df = pd.DataFrame.from_dict(dictinary_list)
df.to_csv("AllBundesligaGamesEver.csv", sep=";")
# Out:
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1963-64/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1964-65/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1965-66/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1966-67/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1967-68/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1968-69/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1969-70/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1970-71/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1971-72/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1972-73/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1973-74/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1974-75/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1975-76/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1976-77/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1977-78/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1978-79/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1979-80/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1980-81/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1981-82/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1982-83/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1983-84/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1984-85/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1985-86/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1986-87/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1987-88/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1988-89/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1989-90/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1990-91/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1991-92/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1992-93/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1993-94/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1994-95/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1995-96/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1996-97/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1997-98/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1998-99/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/1999-00/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2000-01/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2001-02/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2002-03/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2003-04/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2004-05/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2005-06/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2006-07/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2007-08/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2008-09/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2009-10/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2010-11/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2011-12/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2012-13/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2013-14/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2014-15/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2015-16/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2016-17/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2017-18/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2018-19/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/1-bundesliga/2019-20/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1974-75/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1975-76/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1976-77/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1977-78/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1978-79/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1979-80/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1980-81/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1981-82/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1982-83/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1983-84/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1984-85/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1985-86/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1986-87/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1987-88/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1988-89/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1989-90/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1990-91/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1991-92/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1992-93/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1993-94/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1994-95/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1995-96/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1996-97/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1997-98/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1998-99/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/1999-00/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2000-01/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2001-02/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2002-03/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2003-04/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2004-05/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2005-06/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2006-07/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2007-08/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2008-09/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2009-10/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2010-11/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2011-12/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2012-13/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2013-14/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2014-15/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2015-16/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2016-17/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2017-18/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2018-19/-1/0/spieltag.html
# http://www.kicker.de/news/fussball/bundesliga/spieltag/2-bundesliga/2019-20/-1/0/spieltag.html
